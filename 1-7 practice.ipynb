# %%
#return hi for 100 times\
for i in range(0,10):
    print('hi')
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
#reading the input for n times
for i in range(0,6):
    input()
# Out:
#  2
#  3
#  2
#  2
#  2
#  2

# %%
#to read the first line
n=int(input())
# Out:
#  2
